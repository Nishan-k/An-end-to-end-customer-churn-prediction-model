# %%
# %pwd
# Out:
# 'D:\\ML and AI Engineer\\Projects\\An-end-to-end-customer-churn-prediction-model'

# %%
import os
# os.chdir("..")

# %% [markdown]
# # 1. Import the libraries:

# %%
import os
import pandas as pd
import mlflow
import mlflow.sklearn
from mlflow.models.signature import infer_signature
import numpy as np
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (f1_score, precision_score, recall_score,
                              accuracy_score, classification_report,
                              confusion_matrix, ConfusionMatrixDisplay)
from sklearn.ensemble import (RandomForestClassifier, ExtraTreesClassifier,
                               GradientBoostingClassifier)
from src.customer_churn.exception.exception import CustomerChurnException
from src.customer_churn.logging.logger import logging
from xgboost import XGBClassifier
from sklearn.svm import SVC
from scipy.stats import loguniform, uniform
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import joblib
import dagshub
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# %pwd
# Out:
# 'D:\\ML and AI Engineer\\Projects\\An-end-to-end-customer-churn-prediction-model'

# %% [markdown]
# # 2. Configuration:

# %%
mlflow_tracking_uri = os.getenv("MLFLOW_URI")
dagshub_owner_name = os.getenv("REPO_OWNER")
dagshub_repo_name = os.getenv("REPO_NAME")
dagshub_user_token = os.getenv("DAGSHUB_USER_TOKEN")

# %%
mlflow.set_tracking_uri(mlflow_tracking_uri)
dagshub.init(repo_owner=dagshub_owner_name, repo_name=dagshub_repo_name, mlflow=True)
mlflow.set_experiment("churn-prediction-clipped-vs-unclipped")
# Out:
# Accessing as Nishan-k
# Initialized MLflow to track repo "Nishan-k/An-end-to-end-customer-churn-prediction-model"
# Repository Nishan-k/An-end-to-end-customer-churn-prediction-model initialized!
# <Experiment: artifact_location='mlflow-artifacts:/31ea15b41c9542cbb60c2df33cd42bdf', creation_time=1774431138329, experiment_id='1', last_update_time=1774431138329, lifecycle_stage='active', name='churn-prediction-clipped-vs-unclipped', tags={'mlflow.experimentKind': 'custom_model_development'}, workspace='default'>

# %% [markdown]
# # 3. Common functions:

# %%
def create_dep_indep_features(df:pd.DataFrame):
    """
    Splits the data into dependent(y) and independent(X) features:
    """
    df.dropna(inplace=True)
    X = df.drop(columns=['customerid', 'churn'])
    y = df['churn']
    return X, y

# %%
def separate_col_by_dtypes(df:pd.DataFrame) -> list():
    """
    Returns the numerical and categorical feature names as list:
    """
    numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
    categorical_features = df.select_dtypes(include=['object', 'string']).columns.tolist()
    return (numerical_features, categorical_features)

# %%
def log_confusion_matrix(y_true, y_pred,
                          model_name: str, branch: str):
    fig, ax = plt.subplots(figsize=(6, 5))
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=['Retained', 'Churned']
    )
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'{model_name} ({branch}) — Confusion Matrix')
    plt.tight_layout()
    path = f"cm_{model_name}_{branch}.png"
    plt.savefig(path)
    plt.close()
    mlflow.log_artifact(path)
    os.remove(path)

# %% [markdown]
# # 4. Read the data:

# %%
clipped_train = pd.read_parquet("Artifacts/feature_engineering/data_clipped/train.parquet")
clipped_test = pd.read_parquet("Artifacts/feature_engineering/data_clipped/test.parquet")

unclipped_train = pd.read_parquet("Artifacts/feature_engineering/data_unclipped/train.parquet")
unclipped_test = pd.read_parquet("Artifacts/feature_engineering/data_unclipped/test.parquet")

# %% [markdown]
# ## 4.1 Split the data into train and test sets:

# %%
# Clipped data:
X_train_clipped, y_train_clipped = create_dep_indep_features(clipped_train)
X_test_clipped, y_test_clipped = create_dep_indep_features(clipped_test)

# Unclipped data:
X_train_unclipped, y_train_unclipped = create_dep_indep_features(unclipped_train)
X_test_unclipped, y_test_unclipped = create_dep_indep_features(unclipped_test)

# %%
# The column names will be the same for both the brances(clipped & Unclipped):
numerical_features, categorical_features = separate_col_by_dtypes(X_train_clipped)

# %% [markdown]
# ## 4.2 Branch Configuration:

# %%
branches = {
    'clipped': {
        'X_train': X_train_clipped,
        'y_train': y_train_clipped,
        'X_test': X_test_clipped,
        'y_test': y_test_clipped,
        'numerical_features': numerical_features,
        'categorical_features': categorical_features
    },

    'unclipped': {
        'X_train': X_train_unclipped,
        'y_train': y_train_unclipped,
        'X_test': X_test_unclipped,
        'y_test': y_test_unclipped,
        'numerical_features': numerical_features,
        'categorical_features': categorical_features
    }
}

# %% [markdown]
# # 5. Model Configurations:

# %% [markdown]
# #### During spot-checking 5 algorithms were picked:

# %%
model_configs = {
    
    'SVC': {
        'model': SVC(class_weight='balanced', random_state=42,
                     probability=True),
        'params': {
            'clf__C':      loguniform(0.01, 100),
            'clf__kernel': ['rbf', 'linear'],
            'clf__gamma':  ['scale', 'auto']
        }
    },
    
    'GradientBoosting': {
        'model': GradientBoostingClassifier(random_state=42),
        'params': {
            'clf__n_estimators':     [100, 200, 300],
            'clf__learning_rate':    loguniform(0.01, 0.3),
            'clf__max_depth':        [3, 4, 5],
            'clf__subsample':        uniform(0.7, 0.3),
            'clf__min_samples_leaf': [10, 20, 30]
        }
    },
    
    'RandomForest': {
        'model': RandomForestClassifier(class_weight='balanced',
                                         random_state=42),
        'params': {
            'clf__n_estimators':     [100, 200, 300],
            'clf__max_depth':        [None, 5, 10, 20],
            'clf__min_samples_leaf': [1, 5, 10, 20],
            'clf__max_features':     ['sqrt', 'log2']
        }
    },
    
    'ExtraTrees': {
        'model': ExtraTreesClassifier(class_weight='balanced',
                                       random_state=42),
        'params': {
            'clf__n_estimators':     [100, 200, 300],
            'clf__max_depth':        [None, 5, 10, 20],
            'clf__min_samples_leaf': [1, 5, 10, 20],
            'clf__max_features':     ['sqrt', 'log2']
        }
    }
    ,
    
    'XGBoost': {
    'model': XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        random_state=42,
        verbosity=0
    ),
    'params': {
        'clf__n_estimators':     [100, 200, 300],
        'clf__max_depth':        [3, 5, 7, 10],
        'clf__learning_rate':    [0.01, 0.05, 0.1, 0.3],
        'clf__subsample':        [0.6, 0.8, 1.0],
        'clf__colsample_bytree': [0.6, 0.8, 1.0],
        'clf__min_child_weight': [1, 3, 5],
        'clf__gamma':            [0, 0.1, 0.3]
    }
}
}

# %% [markdown]
# # 6. Build the pre-processors and encoders:

# %%
def build_preprocessor(numerical_features, categorical_features):
    preprocessor = ColumnTransformer([
        ('num', RobustScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ], remainder='drop')
    return preprocessor

# %% [markdown]
# # 7. Run the experiments:

# %%
def run_experiment(model_name: str, model, param_grid:dict, 
                   branch_name:str, branch_data:dict, 
                   n_iter:int = 30):
    X_train = branch_data['X_train']
    y_train = branch_data['y_train']
    X_test = branch_data['X_test']
    y_test = branch_data['y_test']
    numerical_features = branch_data['numerical_features']
    categorical_features = branch_data['categorical_features']

    preprocessor = build_preprocessor(numerical_features, categorical_features)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('clf', model)
    ])

    search = RandomizedSearchCV(
        pipeline,
        param_distributions=param_grid,
        n_iter = n_iter,
        scoring = 'f1',
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
        random_state=42,
        n_jobs=-1,
        verbose=0
    )

    run_name = f"{model_name}_{branch_name}"

    with mlflow.start_run(run_name=run_name):
        mlflow.set_tag("model", model_name)
        mlflow.set_tag("branch", branch_name),
        mlflow.set_tag("n_features", str(len(numerical_features + categorical_features)))
        mlflow.set_tag("scaler", "RobustScaler")
        mlflow.set_tag("encoder", "OneHotEncoder")

        start = time.perf_counter()
        search.fit(X_train, y_train)
        duration = round((time.perf_counter() - start)/60, 3)
        best_params = {k.replace('clf__', ''): v for k, v in search.best_params_.items()}
        print(best_params)
        mlflow.log_params(best_params)
        mlflow.log_param("training_duraton_min", duration)
        mlflow.log_metric("cv_f1_best", search.best_score_)

        best_pipeline = search.best_estimator_
        y_pred = best_pipeline.predict(X_test)

        mlflow.log_metric("test_f1", f1_score(y_test, y_pred))
        mlflow.log_metric("test_precision", precision_score(y_test, y_pred))
        mlflow.log_metric("test_recall", recall_score(y_test, y_pred))
        mlflow.log_metric("test_accuracy", accuracy_score(y_test, y_pred))

        log_confusion_matrix(y_test, y_pred, model_name, branch_name)

        print(f"\n{'-'* 50}")
        print(f"Model: {model_name} | Branch: {branch_name}")
        print(f"CV F1: {search.best_score_*100:.2f}% | Duration:{duration}min")
        print(f"Best Params: {best_params}")
        print(classification_report(y_test, y_pred, target_names=['Retained', 'Churned']))

        signature = infer_signature(X_train, y_pred)
        mlflow.sklearn.log_model(
            best_pipeline,
            artifact_path="model",
            signature=signature
        )

        return best_pipeline, search.best_score_, f1_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred)

# %%
all_results = []
trained_pipelines = {} 

for branch_name, branch_data in branches.items():
    print(f"\n{'#'*55}")
    print(f"BRANCH: {branch_name.upper()}")
    print(f"{'#'*55}")

    for model_name, config in model_configs.items():
        pipeline, cv_f1, test_f1, precision, recall = run_experiment(
            model_name=model_name,
            model=config['model'],
            param_grid=config['params'],
            branch_name=branch_name,
            branch_data=branch_data
        )
        key = f"{model_name}_{branch_name}"
        trained_pipelines[key] = {        
            'pipeline': pipeline,
            'branch':   branch_name,
            'X_test':   branch_data['X_test'],
            'y_test':   branch_data['y_test']
        }
        
        all_results.append({
            'model':    model_name,
            'branch':   branch_name,
            'cv_f1':    round(cv_f1 * 100, 2),
            'test_f1':  round(test_f1 * 100, 2),
            'test_precision': round(precision * 100, 2),
            'test_recall': round(recall * 100, 2)
        })
# Out:
# #######################################################
# BRANCH: CLIPPED
# #######################################################
# {'C': np.float64(0.04207988669606638), 'gamma': 'scale', 'kernel': 'rbf'}
# C:\Users\karki\anaconda3\envs\churn_prediction\lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# ...

# %%
results_df = pd.DataFrame(all_results).sort_values(
    'test_f1', ascending=False).reset_index(drop=True)

print("\n=== FINAL COMPARISON — All 8 Experiments ===")
print(results_df.to_string(index=False))

best = results_df.iloc[0]
print(f"\nWinner: {best['model']} on {best['branch']} data")
print(f"Test F1: {best['test_f1']}%")
# Out:
# === FINAL COMPARISON — All 8 Experiments ===
#            model    branch  cv_f1  test_f1  test_precision  test_recall
#       ExtraTrees unclipped  83.81    84.92           76.38        95.59
#       ExtraTrees   clipped  84.19    84.81           76.03        95.87
# GradientBoosting unclipped  84.82    84.54           74.65        97.45
# GradientBoosting   clipped  84.68    84.53           74.66        97.41
#     RandomForest unclipped  84.40    84.49           75.03        96.68
#          XGBoost   clipped  84.90    84.45           74.41        97.62
#     RandomForest   clipped  84.43    84.44           75.10        96.43
#              SVC   clipped  82.31    83.98           74.43        96.33
#          XGBoost unclipped  84.81    83.94           72.96        98.81
#              SVC unclipped  83.17    83.55           72.77        98.08
#
# Winner: ExtraTrees on unclipped data
# Test F1: 84.92%

# %%
from sklearn.metrics import confusion_matrix


results_df['FP'] = 0
results_df['FN'] = 0


for key, item in trained_pipelines.items():
    model_name, branch = key.rsplit('_', 1)
    pipeline = item['pipeline']
    X_test = item['X_test']
    y_test = item['y_test']
    y_pred = pipeline.predict(X_test)
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    
    mask = (results_df['model'] == model_name) & (results_df['branch'] == branch)
    results_df.loc[mask, 'FP'] = fp
    results_df.loc[mask, 'FN'] = fn


print(results_df[['model', 'branch', 'FP', 'FN']].to_string())
# Out:
#               model     branch    FP   FN
# 0        ExtraTrees  unclipped   845  126
# 1        ExtraTrees    clipped   864  118
# 2  GradientBoosting  unclipped   946   73
# 3  GradientBoosting    clipped   945   74
# 4      RandomForest  unclipped   920   95
# 5           XGBoost    clipped   960   68
# 6      RandomForest    clipped   914  102
# 7               SVC    clipped   946  105
# 8           XGBoost  unclipped  1047   34
# 9               SVC  unclipped  1049   55

# %% [markdown]
# - For model selection, I will not just be considering the metrics score but I will calculate the approximate amount the company loses based on **FP** and **FN**.
# - **FP** is the scenario were the model predicts the customer will `churn` but they will stay and the company will wrongly send the offers to retain these customers although not all of them will be `churning`, let's assume the startegy cost will be `10 Euro` per customer.
# - **FN** is the scenario where the `model predicts the customer will stay but they will churn` resulting in losing the customers, and let's assume on average the `Life time value (LTV)` of each customer on average is `200 Euros`.

# %%
offer_cost = 10
customer_value = 200
results_df['amount_in_risk'] = results_df['FP'] * offer_cost + results_df['FN'] * customer_value

# %% [markdown]
# #### Sorting the results based on lower risk amount models

# %%
best_by_cost = results_df.sort_values('amount_in_risk').reset_index(drop=True)

# %%
best_by_cost
# Out:
#               model     branch  cv_f1  test_f1  test_precision  test_recall  \
# 0           XGBoost  unclipped  84.81    83.94           72.96        98.81
# 1               SVC  unclipped  83.17    83.55           72.77        98.08
# 2           XGBoost    clipped  84.90    84.45           74.41        97.62
# 3  GradientBoosting  unclipped  84.82    84.54           74.65        97.45
# 4  GradientBoosting    clipped  84.68    84.53           74.66        97.41
# 5      RandomForest  unclipped  84.40    84.49           75.03        96.68
# 6      RandomForest    clipped  84.43    84.44           75.10        96.43
# 7               SVC    clipped  82.31    83.98           74.43        96.33
# 8        ExtraTrees    clipped  84.19    84.81           76.03        95.87
# 9        ExtraTrees  unclipped  83.81    84.92           76.38        95.59
#
#      FP   FN  amount_in_risk
# 0  1047   34           17270
# 1  1049   55           21490
# 2   960   68           23200
# ...

# %% [markdown]
# ### Model & Data-Branch Selection:

# %% [markdown]
# - `XGBoost` model and `unclipped` data branch has finalized based on the lowest amount at risk.

# %%
best_key = "XGBoost_unclipped"
best_pipeline = trained_pipelines[best_key]['pipeline']
best_params = best_pipeline.named_steps['clf'].get_params()
print(best_params)
# Out:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': 'logloss', 'feature_types': None, 'feature_weights': None, 'gamma': 0.3, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 10, 'max_leaves': None, 'min_child_weight': 3, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 100, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8, 'tree_method': None, 'validate_parameters': None, 'verbosity': 0}

# %% [markdown]
# ## Logging the final model:

# %%
best_row = results_df[(results_df['model'] == 'XGBoost') & (results_df['branch'] == 'unclipped')].iloc[0]

# %%
best_row
# Out:
# model               XGBoost
# branch            unclipped
# cv_f1                 84.81
# test_f1               83.94
# test_precision        72.96
# test_recall           98.81
# FP                     1047
# FN                       34
# amount_in_risk        17270
# Name: 8, dtype: object

# %% [markdown]
# #### Concatenate the data (Unclipped):

# %%
unclipped_full = pd.concat([unclipped_train, unclipped_test])

# %%
X_test_unclipped.shape
# Out:
# (4141, 13)

# %%
unclipped_full.dropna(inplace=True)
X = unclipped_full.drop(columns=['customerid', 'churn'])
y = unclipped_full['churn']

# %% [markdown]
# #### Training the model:

# %%
numerical_features, categorical_features = separate_col_by_dtypes(X)

# %%
preprocessor = ColumnTransformer([
        ('num', RobustScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ], remainder='drop')

final_model = XGBClassifier(**best_params)

final_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('clf', final_model)
])

final_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   ['order_frequency',
#                                                    'total_monetary_value',
#                                                    'total_quantity_abs',
#                                                    'total_order_issues',
#                                                    'avg_order_value',
#                                                    'avg_quantity_per_order',
#                                                    'customer_order_issue_rate',
#                                                    'recency', 'tenure',
#                                                    'avg_stockcode_issue_rate',
#                                                    'max_stockcode_issue_rate',
#                                                    'total_orders_made_for_stock']),
# ...

# %%
mlflow.set_experiment("churn-prediction-final-model")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/c1f665e944d24269b028c8acdc41828d', creation_time=1774737058639, experiment_id='2', last_update_time=1774737058639, lifecycle_stage='active', name='churn-prediction-final-model', tags={}, workspace='default'>

# %%
best_row
# Out:
# model               XGBoost
# branch            unclipped
# cv_f1                 84.81
# test_f1               83.94
# test_precision        72.96
# test_recall           98.81
# FP                     1047
# FN                       34
# amount_in_risk        17270
# Name: 8, dtype: object

# %%
with mlflow.start_run(run_name="final_model_XGBoost_unclipped"):
    mlflow.set_tag("model", "XGBoost")
    mlflow.set_tag("branch", "unclipped")
    mlflow.set_tag("final", "true")
    mlflow.log_params(best_params)
    mlflow.log_metric("cv_f1", best_row['cv_f1'])
    mlflow.log_metric("test_f1", best_row['test_f1'])
    mlflow.log_metric("test_precision", best_row['test_precision'])
    mlflow.log_metric("test_recall", best_row['test_recall'])
    mlflow.log_metric("total_cost", best_row['amount_in_risk'])  
    mlflow.sklearn.log_model(final_pipeline, name="model")
# Out:
# 2026/03/28 23:32:59 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run final_model_XGBoost_unclipped at: https://dagshub.com/Nishan-k/An-end-to-end-customer-churn-prediction-model.mlflow/#/experiments/2/runs/e3821cd47cee41b9a2a46b5e69bcc151
# 🧪 View experiment at: https://dagshub.com/Nishan-k/An-end-to-end-customer-churn-prediction-model.mlflow/#/experiments/2

# %%
unclipped_train.size
# Out:
# 65715
