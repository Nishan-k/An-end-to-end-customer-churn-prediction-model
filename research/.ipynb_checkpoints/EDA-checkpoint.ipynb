# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
os.chdir("..")

# %%
# %pwd
# Out:
# 'D:\\ML and AI Engineer\\Projects\\An-end-to-end-customer-churn-prediction-model'

# %%
clipped_train = pd.read_parquet("Artifacts/feature_engineering/data_clipped/train.parquet")

# %%
clipped_train.describe()
# Out:
#        order_frequency  total_monetary_value  total_quantity_abs  \
# count      4380.000000           4380.000000         4380.000000
# mean          5.351598           1582.029144          853.782192
# std           9.942453           6822.044683         3048.217787
# min           1.000000          -1366.050000            1.000000
# 25%           1.000000            223.177500          124.000000
# 50%           3.000000            532.820000          303.000000
# 75%           6.000000           1344.225000          787.000000
# max         262.000000         268423.640000       104965.000000
#
#        total_order_issues  avg_order_value  avg_quantity_per_order  \
# count         4380.000000      4380.000000             4380.000000
# mean             1.860274       249.784502              142.617681
# std              6.149439       340.129331              158.551935
# min              0.000000      -549.340000                1.000000
# ...

# %%
correlation_df = clipped_train.select_dtypes(include=['int64', 'float64']).corr()

# %%
sns.heatmap(correlation_df)
plt.show()

# %%
skew_info = clipped_train.select_dtypes(include=['int64', 'float64']).skew()

# %%
skew_info
# Out:
# order_frequency                10.467833
# total_monetary_value           23.934547
# total_quantity_abs             18.970707
# total_order_issues             11.178117
# avg_order_value                14.520668
# avg_quantity_per_order          9.852302
# customer_order_issue_rate      17.969173
# recency                         1.271314
# tenure                         -0.391925
# avg_stockcode_issue_rate        8.758748
# max_stockcode_issue_rate        3.153988
# total_orders_made_for_stock     3.604279
# churn                          -0.759224
# dtype: float64
